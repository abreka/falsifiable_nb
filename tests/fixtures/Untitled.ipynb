# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("uVMvHFo0OEA")

# %%
1 + 1 == 2
# Out:
# True

# %% [markdown]
# ```python
# def f():
#     pass
# ```

# %% [markdown]
# # Networked Heterodoxy
# ## A Tale of Two Outcomes
